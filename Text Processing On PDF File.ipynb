# %% [markdown]
# ### Text Processing
#
#
# Date: 14th April 2019
#
# Environment: Python 2.7.11 and Jupyter notebook
#
# ## 1. Introduction
# For this task, I've provided a step by step process on analyzing textual data by pre processing text and producing a vocab file.

# %% [markdown]
# ## 2. Import libraries
# I've used the libraries below to obtain the output for this assignment

# %%
import re
import PyPDF2
import nltk
from nltk.tokenize import RegexpTokenizer
from itertools import chain
from nltk.tokenize import MWETokenizer
from nltk.probability import *
import multiprocessing as mp
from nltk.stem import PorterStemmer

# %% [markdown]
# ## 3. Reading and extracting from PDF
# Using a function from PyPDF2, all the raw text from pdf files can be extracted and stored into a python object for usage throughout the assignment. The expected output of this step is one long string object of the whole document.

# %%
#making page content a string
page_content = ""
import PyPDF2
with open('Unit Guide.pdf','rb') as pdf_file:
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    number_of_pages = read_pdf.getNumPages()
    #iterate through page numbers in range of pages
    for page_number in range(number_of_pages): 
        page = read_pdf.getPage(page_number)
        page_content+= page.extractText()
page_content

# %% [markdown]
# ## 4. Creating separate list for unit codes and combined synopsis and outcome
#
# I've created two lists of unitcode and unit information. The first process is to separate each chunk of unit documents into list. Then, I've had created the two lists of unitcodes and summary information.

# %%
# used it to extract units
p = re.findall('([^ ][A-Z]{3}[0-9]{4})\n',page_content)
units= list(p)
 
# used it to extract summary
summary = re.split('[^ ][A-Z]{3}[0-9]{4}\n',page_content)

summary.pop(0) #dont need first line hence i've popped it
# Out:
# 'Title\nSynopsis\nOutcomes'

# %% [markdown]
# ## 5. Normalize the first letters to lowercase
# I've used the list of summary to normalize the first letters to lowercase. Text cleaning was done in this process. I've removed unwanted symbols and new line space characters. This needs to be done for tokenization to be correct given that "n" in "\n" can be counted in tokenization.

# %%
#lists below to append
sum1 = []
sum2 = []
sum3 = [] 
sum4 = [] 
summary_final = []

# remove new line space with symbol \\n and replace it with space to make it tidier and avoid 'n' being attached to a word
i = 0
for each in summary:
    sub = re.sub(r'\\n', " ", summary[i])
    sum1.append(sub)
    i += 1
    
# remove new line space with symbol \n and replace it with space to make it tidier and avoid 'n' being attached to a word
i = 0
for each in sum1:
    sub = re.sub(r'\n', " ", sum1[i])
    sum2.append(sub)
    i += 1
    
# remove the bracket symbols "[" that exists in outcome to make it tidier.
for each in sum2:
    sub = re.sub(r'\[\'', "", each)
    sum3.append(sub)

# remove the bracket symbols "]" that exists in outcome to make it tidier.
for each in sum3:
    sub = re.sub(r'\'\]', "", each)
    sum4.append(sub)
    
# remove comma and whitespace in outcomes that comes after fullstop so that lowercase function can be applied 
for each in sum4:
    sub = re.sub(r'\',\s\'', " ", each)
    summary_final.append(sub)

# %%
# empty list to append on
normalize = []
summary_list = []
# using regex to get the first capital letter after full stop and replacing it with the same match regex alphabet
# but with lowercase
for each in summary_final:
    lower = re.sub(r'((?<=\.\s)[A-Z])', 
                   lambda match: r'{}'.format(match.group(1).lower()),each) 
    
    normalize.append(lower) 

# applying lowercase function for the first sentence only because it doesnt start with a full 
#stop.
for each in normalize:
    # using index 0 to get the first alphabet index
    summary_list.append(each.replace(each[0],each[0].lower()))

# %%
# renaming units to units_total for easier reference
p = re.findall('[^ ]([A-Z]{3}[0-9]{4})\n',page_content)
units_total= list(p)

# %%
# creating dictionary for units_total and summary_list
sum1 = dict(zip(units_total,summary_list))

# %% [markdown]
# ## 5. Tokenize summary for every units using regular expression,  "\w+(?:[-']\w+)?
# After normalizing the texts, I have tokenize the units with regular expression tokenizer implemented in NLTK. The code below is in reference to the tutorial

# %%
#tokenizing based on regex word below
tokenizer = RegexpTokenizer("\w+(?:[-']\w+)?")

def tokenizeunits(units):

    token =  sum1[units] 
    tokenized = tokenizer.tokenize(token)
    tokenized_unit = list(set(tokenized))
    return(units, tokenized_unit) # return a tuple of units and a list of tokens

# created a dictionary 
units_tokenized = dict(tokenizeunits(units) for units in sum1.keys())

# %% [markdown]
# ## 6. Finding first 200 meaningful bigrams using PMI  measure.

# %%
#creating bigrams
all_words = list(chain.from_iterable(units_tokenized.values()))

# %% [markdown]
# ## 7. Removing tokens with the length less than 3 from the vocab.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_measures
bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(all_words)
bigram_finder
#more than 20 times frequency
bigram_finder.apply_freq_filter(20)
bigram_finder.apply_word_filter(lambda w: len(w) < 3)# 
top_200_bigrams = bigram_finder.nbest(bigram_measures.pmi, 200) # Top-200 bigrams
top_200_bigrams
# Out:
# [('skills', 'analysis'),
#  ('the', 'able'),
#  ('research', 'skills'),
#  ('with', 'and'),
#  ('this', 'research'),
#  ('skills', 'for')]

# %%
# using MWE tokenizer to obtain top 200 bigrams
mwetokenizer = MWETokenizer(top_200_bigrams)
colloc_patents =  dict((units_total, mwetokenizer.tokenize(summary_list)) for units_total,summary_list in units_tokenized.items())
all_words_colloc = list(chain.from_iterable(colloc_patents.values()))
colloc_voc = list(set(all_words_colloc))

# %% [markdown]
# ## 8. Remove Stopwords

# %%
#open stopwords folder
with open('stopwords_en.txt') as f:
    stopwords = f.read()

# %%
#stopwords removed
tokenized_units_1 = {}
for units in sum1.keys():
    tokenized_units_1[units] = [w for w in units_tokenized[units] if w not in stopwords]

# %% [markdown]
# ## 9. Removing context - independent and context dependent using frequency distribution

# %%
words = list(chain.from_iterable([set(value) for value in tokenized_units_1.values()]))
# use freqdist to get frequency of words
fd = FreqDist(words)
r = fd.most_common()

# %%
r = fd.most_common()
r
# Out:
# [('unit', 146),
#  ('students', 110),
#  ('skills', 97),
#  ('research', 80),
#  ('understanding', 76),
#  ('develop', 69),
#  ('knowledge', 62),
#  ('apply', 61),
#  ('analyse', 61),
#  ('issues', 60),
#  ('including', 59),
#  ('critically', 57),
#  ('practice', 51),
#  ('concepts', 51),
#  ('evaluate', 50),
#  ('principles', 49),
#  ('identify', 49),
#  ('design', 49),
#  ('analysis', 48),
#  ('range', 48),
#  ('demonstrate', 46),
#  ('work', 46),
#  ('critical', 46),
#  ('techniques', 45),
#  ('context', 44),
#  ('health', 43),
#  ('development', 42),
#  ('key', 41),
#  ('contemporary', 39),
#  ('learning', 39),
#  ('social', 39),
#  ('role', 38),
#  ('management', 38),
#  ('explain', 38),
#  ('process', 37),
#  ('topics', 37),
#  ('relevant', 37),
#  ('communication', 36),
#  ('professional', 35),
#  ('project', 35),
#  ('methods', 34),
#  ('understand', 33),
#  ('ability', 32),
#  ('advanced', 31),
#  ('writing', 31),
#  ('cultural', 31),
#  ('communicate', 30),
#  ('strategies', 29),
#  ('reflect', 28),
#  ('discuss', 28),
#  ('practices', 28),
#  ('based', 28),
#  ('interpret', 28),
#  ('practical', 28),
#  ('theoretical', 27),
#  ('individual', 27),
#  ('specific', 27),
#  ('environment', 26),
#  ('processes', 26),
#  ('written', 26),
#  ('approaches', 26),
#  ('basic', 26),
#  ('study', 25),
#  ('oral', 25),
#  ('systems', 25),
#  ('developed', 24),
#  ('application', 24),
#  ('safety', 24),
#  ('occupational', 24),
#  ('focus', 24),
#  ('data', 24),
#  ('presentation', 24),
#  ('contexts', 24),
#  ('problems', 23),
#  ('developing', 23),
#  ('theory', 23),
#  ('theories', 23),
#  ('aspects', 23),
#  ('literature', 23),
#  ('variety', 22),
#  ('challenges', 22),
#  ('projects', 22),
#  ('assess', 22),
#  ('language', 22),
#  ('ethical', 22),
#  ('studies', 22),
#  ('global', 22),
#  ('explore', 21),
#  ('introduces', 21),
#  ('effective', 21),
#  ('business', 21),
#  ('culture', 21),
#  ('society', 21),
#  ('legal', 21),
#  ('performance', 20),
#  ('clinical', 20),
#  ('introduction', 20),
#  ('problem', 20),
#  ('Understand', 20),
#  ('related', 20),
#  ('include', 20),
#  ('present', 20),
#  ('discipline', 19),
#  ('required', 19),
#  ('Demonstrate', 19),
#  ('political', 19),
#  ('academic', 19),
#  ('examine', 19),
#  ('impact', 19),
#  ('assessment', 18),
#  ('thinking', 18),
#  ('level', 18),
#  ('activities', 18),
#  ('rules', 18),
#  ('human', 18),
#  ('major', 18),
#  ('structure', 18),
#  ('program', 17),
#  ('applications', 17),
#  ('system', 17),
#  ('models', 17),
#  ('conduct', 17),
#  ('team', 17),
#  ('designed', 17),
#  ('world', 17),
#  ('undertake', 17),
#  ('production', 16),
#  ('covered', 16),
#  ('area', 16),
#  ('approach', 16),
#  ('effectively', 16),
#  ('synthesise', 16),
#  ('texts', 16),
#  ('international', 16),
#  ('history', 16),
#  ('scientific', 16),
#  ('public', 15),
#  ('effects', 15),
#  ('care', 15),
#  ('historical', 15),
#  ('information', 15),
#  ('examines', 15),
#  ('applied', 15),
#  ('experience', 15),
#  ('settings', 14),
#  ('control', 14),
#  ('elements', 14),
#  ('recognise', 14),
#  ('conceptual', 14),
#  ('framework', 14),
#  ('sources', 14),
#  ('medical', 14),
#  ('industry', 14),
#  ('group', 14),
#  ('evidence', 14),
#  ('diverse', 14),
#  ('working', 14),
#  ('aims', 14),
#  ('common', 14),
#  ('awareness', 13),
#  ('outcomes', 13),
#  ('delivery', 13),
#  ('student', 13),
#  ('analytical', 13),
#  ('nature', 13),
#  ('involved', 13),
#  ('order', 13),
#  ('levels', 13),
#  ('making', 13),
#  ('procedures', 13),
#  ('appreciation', 13),
#  ('relating', 13),
#  ('complex', 13),
#  ('opportunity', 13),
#  ('community', 13),
#  ('explores', 13),
#  ('relation', 13),
#  ('engage', 13),
#  ('physical', 13),
#  ('implement', 13),
#  ('case', 13),
#  ('findings', 13),
#  ('modern', 13),
#  ('service', 12),
#  ('treatment', 12),
#  ('technologies', 12),
#  ('fundamental', 12),
#  ('important', 12),
#  ('perspective', 12),
#  ('introduced', 12),
#  ('methodology', 12),
#  ('studio', 12),
#  ('solutions', 12),
#  ('Describe', 12),
#  ('solving', 12),
#  ('visual', 12),
#  ('field', 12),
#  ('report', 12),
#  ('questions', 12),
#  ('construct', 12),
#  ('local', 12),
#  ('implications', 12),
#  ('policy', 12),
#  ('areas', 12),
#  ('experiences', 12),
#  ('Apply', 12),
#  ('number', 11),
#  ('financial', 11),
#  ('tools', 11),
#  ('select', 11),
#  ('quality', 11),
#  ('engineering', 11),
#  ('materials', 11),
#  ('aim', 11),
#  ('articulate', 11),
#  ('frameworks', 11),
#  ('Develop', 11),
#  ('behaviour', 11),
#  ('planning', 11),
#  ('Australia', 11),
#  ('address', 11),
#  ('standards', 11),
#  ('plan', 11),
#  ('selected', 11),
#  ('types', 11),
#  ('learn', 11),
#  ('Identify', 11),
#  ('Critically', 11),
#  ('prepare', 11),
#  ('concept', 11),
#  ('perspectives', 11),
#  ('ethics', 11),
#  ('components', 11),
#  ('conditions', 11),
#  ('programs', 11),
#  ('individuals', 10),
#  ('relationship', 10),
#  ('completion', 10),
#  ('preparation', 10),
#  ('covers', 10),
#  ('comprehensive', 10),
#  ('primary', 10),
#  ('methodologies', 10),
#  ('material', 10),
#  ('write', 10),
#  ('independent', 10),
#  ('laboratory', 10),
#  ('appraise', 10),
#  ('make', 10),
#  ('ideas', 10),
#  ('limitations', 10),
#  ('decisions', 10),
#  ('cultures', 10),
#  ('influence', 10),
#  ('focuses', 10),
#  ('acquisition', 10),
#  ('environmental', 10),
#  ('high', 10),
#  ('presented', 10),
#  ('independently', 9),
#  ('applying', 9),
#  ('environments', 9),
#  ('disciplines', 9),
#  ('risk', 9),
#  ('organisational', 9),
#  ('introduce', 9),
#  ('setting', 9),
#  ('support', 9),
#  ('selection', 9),
#  ('importance', 9),
#  ('marketing', 9),
#  ('Be', 9),
#  ('enable', 9),
#  ('produce', 9),
#  ('investigation', 9),
#  ('compare', 9),
#  ('software', 9),
#  ('science', 9),
#  ('multidisciplinary', 9),
#  ('Discuss', 9),
#  ('broad', 9),
#  ('undertaking', 9),
#  ('groups', 9),
#  ('integrate', 9),
#  ('subject', 9),
#  ('arguments', 9),
#  ('diversity', 9),
#  ('gained', 9),
#  ('reading', 9),
#  ('national', 9),
#  ('units', 9),
#  ('evaluation', 9),
#  ('digital', 9),
#  ('emphasis', 9),
#  ('organisations', 9),
#  ('debates', 9),
#  ('set', 9),
#  ('review', 9),
#  ('basis', 9),
#  ('examined', 9),
#  ('Analyse', 9),
#  ('features', 9),
#  ('personal', 8),
#  ('creative', 8),
#  ('relate', 8),
#  ('workplace', 8),
#  ('final', 8),
#  ('interventions', 8),
#  ('situations', 8),
#  ('involving', 8),
#  ('complete', 8),
#  ('discussed', 8),
#  ('functions', 8),
#  ('works', 8),
#  ('series', 8),
#  ('familiar', 8),
#  ('collaborative', 8),
#  ('expected', 8),
#  ('relationships', 8),
#  ('Design', 8),
#  ('disease', 8),
#  ('therapy', 8),
#  ('Australian', 8),
#  ('opportunities', 8),
#  ('critique', 8),
#  ('managing', 8),
#  ('competence', 8),
#  ('topic', 8),
#  ('results', 8),
#  ('means', 8),
#  ('text', 8),
#  ('observation', 8),
#  ('investigate', 8),
#  ('operation', 8),
#  ('options', 8),
#  ('images', 8),
#  ('reports', 8),
#  ('encouraged', 8),
#  ('utilise', 8),
#  ('Japanese', 8),
#  ('life', 8),
#  ('define', 8),
#  ('model', 8),
#  ('manage', 8),
#  ('factors', 8),
#  ('interpretation', 8),
#  ('century', 8),
#  ('relations', 8),
#  ('collaboratively', 7),
#  ('evolving', 7),
#  ('foundation', 7),
#  ('responses', 7),
#  ('managers', 7),
#  ('leadership', 7),
#  ('prevention', 7),
#  ('equipment', 7),
#  ('detail', 7),
#  ('construction', 7),
#  ('objectives', 7),
#  ('meet', 7),
#  ('continue', 7),
#  ('potential', 7),
#  ('extended', 7),
#  ('sustainable', 7),
#  ('capacity', 7),
#  ('acquired', 7),
#  ('forms', 7),
#  ('solve', 7),
#  ('intervention', 7),
#  ('family', 7),
#  ('radiation', 7),
#  ('medicine', 7),
#  ('analysing', 7),
#  ('quantitative', 7),
#  ('overview', 7),
#  ('stages', 7),
#  ('structures', 7),
#  ('industrial', 7),
#  ('considered', 7),
#  ('roles', 7),
#  ('terms', 7),
#  ('measurement', 7),
#  ('period', 7),
#  ('core', 7),
#  ('previous', 7),
#  ('integrated', 7),
#  ('implementation', 7),
#  ('Research', 7),
#  ('Japan', 7),
#  ('sophisticated', 7),
#  ('class', 7),
#  ('requirements', 7),
#  ('Recognise', 7),
#  ('3', 7),
#  ('acquire', 7),
#  ('improve', 7),
#  ('central', 7),
#  ('imaging', 7),
#  ('resources', 7),
#  ('policies', 7),
#  ('function', 7),
#  ('general', 7),
#  ('responsible', 7),
#  ('reference', 7),
#  ('characteristics', 7),
#  ('decision', 7),
#  ('diseases', 7),
#  ('creation', 7),
#  ('workshops', 7),
#  ('economic', 7),
#  ('supervisor', 6),
#  ('experimentation', 6),
#  ('peers', 6),
#  ('commercial', 6),
#  ('task', 6),
#  ('chosen', 6),
#  ('themes', 6),
#  ('lectures', 6),
#  ('considerations', 6),
#  ('attitudes', 6),
#  ('strategic', 6),
#  ('presentations', 6),
#  ('Have', 6),
#  ('employ', 6),
#  ('patients', 6),
#  ('patient', 6),
#  ('clients', 6),
#  ('Evaluate', 6),
#  ('evidence-based', 6),
#  ('in-depth', 6),
#  ('designs', 6),
#  ('reporting', 6),
#  ('1', 6),
#  ('foundations', 6),
#  ('online', 6),
#  ('people', 6),
#  ('source', 6),
#  ('legislation', 6),
#  ('formulate', 6),
#  ('Work', 6),
#  ('manner', 6),
#  ('career', 6),
#  ('video', 6),
#  ('documents', 6),
#  ('sound', 6),
#  ('problem-solving', 6),
#  ('twentieth', 6),
#  ('simple', 6),
#  ('devices', 6),
#  ('styles', 6),
#  ('values', 6),
#  ('innovative', 6),
#  ('Explain', 6),
#  ('interactions', 6),
#  ('biological', 6),
#  ('future', 6),
#  ('challenge', 6),
#  ('dealing', 6),
#  ('accordance', 6),
#  ('create', 6),
#  ('properties', 6),
#  ('games', 6),
#  ('develops', 6),
#  ('communities', 6),
#  ('successful', 6),
#  ('solution', 6),
#  ('essential', 6),
#  ('politics', 6),
#  ('modelling', 6),
#  ('test', 6),
#  ('broader', 6),
#  ('promotion', 6),
#  ('services', 6),
#  ('standard', 6),
#  ('behavioural', 5),
#  ('contribution', 5),
#  ('contribute', 5),
#  ('training', 5),
#  ('employee', 5),
#  ('therapeutic', 5),
#  ('proficiency', 5),
#  ('practitioners', 5),
#  ('summative', 5),
#  ('perform', 5),
#  ('measure', 5),
#  ('processing', 5),
#  ('operations', 5),
#  ('instrumentation', 5),
#  ('includes', 5),
#  ('computer', 5),
#  ('determine', 5),
#  ('sequence', 5),
#  ('leading', 5),
#  ('drug', 5),
#  ('specifically', 5),
#  ('response', 5),
#  ('illness', 5),
#  ('qualitative', 5),
#  ('guide', 5),
#  ('original', 5),
#  ('consumer', 5),
#  ('tasks', 5),
#  ('record', 5),
#  ('Reflect', 5),
#  ('electronic', 5),
#  ('organisation', 5),
#  ('teams', 5),
#  ('enhance', 5),
#  ("student's", 5),
#  ('Honours', 5),
#  ('forces', 5),
#  ('year', 5),
#  ('psychology', 5),
#  ('African', 5),
#  ('articles', 5),
#  ('emerging', 5),
#  ('successfully', 5),
#  ('A', 5),
#  ('architecture', 5),
#  ('experiment', 5),
#  ('law', 5),
#  ('Communicate', 5),
#  ('United', 5),
#  ('regional', 5),
#  ('platforms', 5),
#  ('defined', 5),
#  ('utilising', 5),
#  ('consist', 5),
#  ('objects', 5),
#  ('evolution', 5),
#  ('European', 5),
#  ('cross-cultural', 5),
#  ('question', 5),
#  ('measures', 5),
#  ('English', 5),
#  ('technical', 5),
#  ('countries', 5),
#  ('orally', 5),
#  ('popular', 5),
#  ('identity', 5),
#  ('interaction', 5),
#  ('state', 5),
#  ('content', 5),
#  ('fields', 5),
#  ('thesis', 5),
#  ('regulation', 5),
#  ('safe', 5),
#  ('mechanisms', 5),
#  ('audiences', 5),
#  ('instruments', 5),
#  ('exposed', 5),
#  ('interactive', 5),
#  ('laws', 5),
#  ('curriculum', 5),
#  ('responsibility', 5),
#  ('goals', 5),
#  ('multiple', 5),
#  ('rights', 5),
#  ('builds', 5),
#  ('accounting', 5),
#  ('everyday', 5),
#  ('synthesis', 5),
#  ('generate', 5),
#  ('molecular', 5),
#  ('introducing', 5),
#  ('explored', 5),
#  ('criteria', 5),
#  ('method', 5),
#  ('linguistic', 5),
#  ('War', 5),
#  ('developmental', 5),
#  ('experimental', 5),
#  ('presenting', 5),
#  ('specialist', 5),
#  ('risks', 5),
#  ('rationale', 5),
#  ('existing', 5),
#  ('build', 5),
#  ('product', 5),
#  ('exploration', 5),
#  ('completed', 5),
#  ('informed', 5),
#  ('stakeholders', 5),
#  ('competency', 5),
#  ('underpinning', 5),
#  ('competently', 5),
#  ('developments', 5),
#  ('strategy', 5),
#  ('account', 4),
#  ('University', 4),
#  ('network', 4),
#  ('established', 4),
#  ('confidence', 4),
#  ('psychological', 4),
#  ('display', 4),
#  ('multi-disciplinary', 4),
#  ('devise', 4),
#  ('tests', 4),
#  ('capabilities', 4),
#  ('additional', 4),
#  ('employees', 4),
#  ('face', 4),
#  ('expression', 4),
#  ('calculate', 4),
#  ('combined', 4),
#  ('I', 4),
#  ('chemical', 4),
#  ('hazards', 4),
#  ('mechanical', 4),
#  ('plant', 4),
#  ('detailed', 4),
#  ('tutorials', 4),
#  ('goods', 4),
#  ('collaborate', 4),
#  ('documentation', 4),
#  ('appraisal', 4),
#  ('vocabulary', 4),
#  ('experiments', 4),
#  ('encompassing', 4),
#  ('drugs', 4),
#  ('cover', 4),
#  ('shape', 4),
#  ('object', 4),
#  ('Master', 4),
#  ('exercises', 4),
#  ('concerned', 4),
#  ('built', 4),
#  ('narrative', 4),
#  ('underpin', 4),
#  ('centred', 4),
#  ('applicability', 4),
#  ('fieldwork', 4),
#  ('portfolio', 4),
#  ('Implement', 4),
#  ('placement', 4),
#  ('result', 4),
#  ('governance', 4),
#  ('behaviours', 4),
#  ('prior', 4),
#  ('guidance', 4),
#  ('shaped', 4),
#  ('collection', 4),
#  ('locate', 4),
#  ('active', 4),
#  ('grammar', 4),
#  ('increasingly', 4),
#  ('progress', 4),
#  ('testing', 4),
#  ('formulated', 4),
#  ('conventions', 4),
#  ('communications', 4),
#  ('obligations', 4),
#  ('events', 4),
#  ('stories', 4),
#  ('status', 4),
#  ('intellectual', 4),
#  ('judgement', 4),
#  ('interests', 4),
#  ('interested', 4),
#  ('image', 4),
#  ('open', 4),
#  ('child', 4),
#  ('regulations', 4),
#  ('age', 4),
#  ('justify', 4),
#  ('sessions', 4),
#  ('undertaken', 4),
#  ('private', 4),
#  ('addition', 4),
#  ('reflective', 4),
#  ('component', 4),
#  ('consultation', 4),
#  ('choose', 4),
#  ('literary', 4),
#  ('teaching', 4),
#  ('regular', 4),
#  ('fundamentals', 4),
#  ('situation', 4),
#  ('regulatory', 4),
#  ('diagnostic', 4),
#  ('physiology', 4),
#  ('differences', 4),
#  ('summarise', 4),
#  ('express', 4),
#  ('difference', 4),
#  ('textual', 4),
#  ('identifying', 4),
#  ('Project', 4),
#  ('addressing', 4),
#  ('changing', 4),
#  ('sexual', 4),
#  ('movements', 4),
#  ('flow', 4),
#  ('employed', 4),
#  ('real-world', 4),
#  ('operate', 4),
#  ('scales', 4),
#  ('criminal', 4),
#  ('argument', 4),
#  ('comparative', 4),
#  ('needed', 4),
#  ('contextual', 4),
#  ('What', 4),
#  ('good', 4),
#  ('affect', 4),
#  ('achieve', 4),
#  ('technology', 4),
#  ('Africa', 4),
#  ('justice', 4),
#  ('alternative', 4),
#  ('package', 4),
#  ('examination', 4),
#  ('entities', 4),
#  ('governing', 4),
#  ('statements', 4),
#  ('structural', 4),
#  ('physics', 4),
#  ('power', 4),
#  ('solid', 4),
#  ('exposure', 4),
#  ('Formulate', 4),
#  ('intensive', 4),
#  ('Synthesise', 4),
#  ('epidemiology', 4),
#  ('pathophysiology', 4),
#  ('ongoing', 4),
#  ('terminology', 4),
#  ('Chinese', 4),
#  ('reasons', 4),
#  ('companies', 4),
#  ('discourse', 4),
#  ('large', 4),
#  ('mobile', 4),
#  ('gender', 4),
#  ('market', 4),
#  ('cost', 4),
#  ('direct', 4),
#  ('programming', 4),
#  ('contributing', 4),
#  ('ensure', 4),
#  ('examples', 4),
#  ('integration', 4),
#  ('Practice', 4),
#  ('analytic', 4),
#  ('contrast', 4),
#  ('finally', 4),
#  ('philosophical', 4),
#  ('religious', 4),
#  ('play', 4),
#  ('philosophy', 4),
#  ('empirical', 4),
#  ('significance', 4),
#  ('involves', 4),
#  ('taking', 4),
#  ('discourses', 4),
#  ('operational', 4),
#  ('combination', 4),
#  ('publication', 4),
#  ('experienced', 4),
#  ('underlying', 4),
#  ('outcome', 4),
#  ('Produce', 4),
#  ('3D', 4),
#  ('region', 4),
#  ('require', 4),
#  ('World', 4),
#  ('interest', 4),
#  ('stage', 4),
#  ('inquiry', 4),
#  ('protocols', 4),
#  ('institutional', 4),
#  ('leaders', 4),
#  ('crisis', 4),
#  ('decision-making', 4),
#  ('creatively', 4),
#  ('view', 4),
#  ('diagnosis', 4),
#  ('responsibilities', 4),
#  ('objective', 4),
#  ('discussion', 4),
#  ('participate', 4),
#  ('coordinator', 3),
#  ('skill', 3),
#  ('qualities', 3),
#  ('receive', 3),
#  ('virtual', 3),
#  ('collaboration', 3),
#  ('reflects', 3),
#  ('creativity', 3),
#  ('finance', 3),
#  ('demonstrated', 3),
#  ('practitioner', 3),
#  ('music', 3),
#  ('2', 3),
#  ('dynamics', 3),
#  ('type', 3),
#  ('optimise', 3),
#  ('involve', 3),
#  ('positive', 3),
#  ('heat', 3),
#  ('pressure', 3),
#  ('teamwork', 3),
#  ('scope', 3),
#  ('operating', 3),
#  ('distribution', 3),
#  ('flows', 3),
#  ('increased', 3),
#  ('exchange', 3),
#  ('modes', 3),
#  ('interdisciplinary', 3),
#  ('focused', 3),
#  ('fine', 3),
#  ('considerable', 3),
#  ('fabrication', 3),
#  ('force', 3),
#  ('tissue', 3),
#  ('parallel', 3),
#  ('algorithms', 3),
#  ('dimensional', 3),
#  ('Studio', 3),
#  ('interface', 3),
#  ('enquiry', 3),
#  ('Observe', 3),
#  ('Strait', 3),
#  ('equity', 3),
#  ('Islander', 3),
#  ('trends', 3),
#  ('secondary', 3),
#  ('self-directed', 3),
#  ('arising', 3),
#  ('provision', 3),
#  ('scenario', 3),
#  ('competencies', 3),
#  ('contract', 3),
#  ('supervision', 3),
#  ('reflection', 3),
#  ('life-long', 3),
#  ('reach', 3),
#  ('resource', 3),
#  ('commerce', 3),
#  ('matter', 3),
#  ('attitude', 3),
#  ('continuation', 3),
#  ('sex', 3),
#  ('South', 3),
#  ('complements', 3),
#  ('integrating', 3),
#  ('interpreting', 3),
#  ('generating', 3),
#  ('investigating', 3),
#  ('journal', 3),
#  ('significant', 3),
#  ('authentic', 3),
#  ('point', 3),
#  ('enhanced', 3),
#  ('offered', 3),
#  ('An', 3),
#  ('weekly', 3),
#  ('inherent', 3),
#  ('space', 3),
#  ('engaging', 3),
#  ('activity', 3),
#  ('site', 3),
#  ('creating', 3),
#  ('compelling', 3),
#  ('journalism', 3),
#  ('audio', 3),
#  ('building', 3),
#  ('fraud', 3),
#  ('independence', 3),
#  ('property', 3),
#  ('arise', 3),
#  ('meaning', 3),
#  ('System', 3),
#  ('Advanced', 3),
#  ('aimed', 3),
#  ('universities', 3),
#  ('academia', 3),
#  ('Monash', 3),
#  ('States', 3),
#  ('animation', 3),
#  ('benefits', 3),
#  ('formats', 3),
#  ('resolution', 3),
#  ('multimedia', 3),
#  ('giving', 3),
#  ('identification', 3),
#  ('living', 3),
#  ('consideration', 3),
#  ('discrimination', 3),
#  ('abuse', 3),
#  ('trauma', 3),
#  ('start', 3),
#  ('proposed', 3),
#  ('Practices', 3),
#  ('contact', 3),
#  ('completing', 3),
#  ('supervised', 3),
#  ('government', 3),
#  ('periods', 3),
#  ('underpinned', 3),
#  ('centuries', 3),
#  ('made', 3),
#  ('Europe', 3),
#  ('strengths', 3),
#  ('gap', 3),
#  ('translation', 3),
#  ('000', 3),
#  ('spoken', 3),
#  ('grammatical', 3),
#  ('short', 3),
#  ('mastery', 3),
#  ('extension', 3),
#  ('conversation', 3),
#  ('relates', 3),
#  ('effectiveness', 3),
#  ('anatomy', 3),
#  ('prototype', 3),
#  ('continuing', 3),
#  ('regimes', 3),
#  ('natural', 3),
#  ('variation', 3),
#  ('intercultural', 3),
#  ('drawing', 3),
#  ('listening', 3),
#  ('discussions', 3),
#  ('speaking', 3),
#  ('essay', 3),
#  ('formal', 3),
#  ('appropriately', 3),
#  ('familiarity', 3),
#  ('audience', 3),
#  ('traditional', 3),
#  ('conducted', 3),
#  ('scholars', 3),
#  ('sexuality', 3),
#  ('Select', 3),
#  ('fluid', 3),
#  ('transfer', 3),
#  ('consumers', 3),
#  ('surface', 3),
#  ('Define', 3),
#  ('complexity', 3),
#  ('conclusions', 3),
#  ('issue', 3),
#  ('draws', 3),
#  ('employment', 3),
#  ('offers', 3),
#  ('answers', 3),
#  ('contested', 3),
#  ('globalisation', 3),
#  ('internationally', 3),
#  ('specialised', 3),
#  ('providing', 3),
#  ('share', 3),
#  ('disclosure', 3),
#  ('cash', 3),
#  ('recognition', 3),
#  ('Italian', 3),
#  ('past', 3),
#  ('packages', 3),
#  ('studying', 3),
#  ('controls', 3),
#  ('assurance', 3),
#  ('detection', 3),
#  ('vehicle', 3),
#  ('draw', 3),
#  ('sensors', 3),
#  ('dimensions', 3),
#  ('transport', 3),
#  ('analytically', 3),
#  ('Determine', 3),
#  ('access', 3),
#  ('corporate', 3),
#  ('security', 3),
#  ('promote', 3),
#  ('Outline', 3),
#  ('reproductive', 3),
#  ('infection', 3),
#  ('nursing', 3),
#  ('scholarly', 3),
#  ('wider', 3),
#  ('strong', 3),
#  ('proposal', 3),
#  ('hypothesis', 3),
#  ('budgeting', 3),
#  ('markets', 3),
#  ('firm', 3),
#  ('capital', 3),
#  ('forward', 3),
#  ('rendering', 3),
#  ('propose', 3),
#  ('papers', 3),
#  ('affected', 3),
#  ('small', 3),
#  ('document', 3),
#  ('surveys', 3),
#  ('Undertake', 3),
#  ('abilities', 3),
#  ('collect', 3),
#  ...]

# %%
#getting list of more than 95% frequency
list_of_mostcommon = []
for i in r:
    word,freq = i
    if freq > 0.95 * len(sum1):
        le = (word, freq)
        list_of_mostcommon.append(word)
list_of_mostcommon
# Out:
# []

# %%
# checking for least common words
p = fd.most_common()[::-1]
p
# Out:
# [('paddock', 1),
#  ('household', 1),
#  ('agricultural', 1),
#  ('impacting', 1),
#  ('salinity', 1),
#  ('views', 1),
#  ('economists', 1),
#  ('plate', 1),
#  ('beneficial', 1),
#  ('messages', 1),
#  ('initiatives', 1),
#  ('nutritional', 1),
#  ('drive', 1),
#  ('drought', 1),
#  ('intake', 1),
#  ('Industrial', 1),
#  ('IDN4001', 1),
#  ('perfect', 1),
#  ('serve', 1),
#  ('initiated', 1),
#  ('One', 1),
#  ('Major', 1),
#  ('Cultivate', 1),
#  ('ambitions', 1),
#  ('species', 1),
#  ('genetics', 1),
#  ('practicals', 1),
#  ('drift', 1),
#  ('discoveries', 1),
#  ('mutation', 1),
#  ('high-level', 1),
#  ('invasive', 1),
#  ('mating', 1),
#  ('biodiversity', 1),
#  ('verse', 1),
#  ('Symbolist', 1),
#  ('Modernist', 1),
#  ('ideogramic', 1),
#  ('automatic', 1),
#  ('parataxis', 1),
#  ('free', 1),
#  ('agreement', 1),
#  ('requests', 1),
#  ('Introductory', 1),
#  ('routine', 1),
#  ('lifetime', 1),
#  ('refusal', 1),
#  ('Classification', 1),
#  ('accommodating', 1),
#  ('improving', 1),
#  ('classroom', 1),
#  ('childhood', 1),
#  ('neurodevelopmental', 1),
#  ('learner', 1),
#  ('impairments', 1),
#  ('occur', 1),
#  ('etiology', 1),
#  ('Disability', 1),
#  ('Charter', 1),
#  ('WHO', 1),
#  ('facilitates', 1),
#  ('Functioning', 1),
#  ('preschool', 1),
#  ('leisure', 1),
#  ("child's", 1),
#  ('parents', 1),
#  ('co-existing', 1),
#  ('Social', 1),
#  ('premises', 1),
#  ('neurodevelopment', 1),
#  ('motor', 1),
#  ('disabilities', 1),
#  ('ICF', 1),
#  ("member's", 1),
#  ('traffic-related', 1),
#  ('pre-existing', 1),
#  ('exposes', 1),
#  ('intersection', 1),
#  ('driver', 1),
#  ('survey', 1),
#  ('collected', 1),
#  ('strengthen', 1),
#  ('sourced', 1),
#  ('bi-weekly', 1),
#  ('commentaries', 1),
#  ('two-hour', 1),
#  ('Chinese-language', 1),
#  ('Chinese-speaking', 1),
#  ('project-based', 1),
#  ('mainland', 1),
#  ('abroad', 1),
#  ('English-language', 1),
#  ('manifests', 1),
#  ('FIt5144', 1),
#  ('timely', 1),
#  ('PhD', 1),
#  ('employability', 1),
#  ('funding', 1),
#  ('publish', 1),
#  ('Mid-Candidature', 1),
#  ('phD', 1),
#  ('Review', 1),
#  ('Philosophy', 1),
#  ('generic', 1),
#  ('forums', 1),
#  ('Progress', 1),
#  ('elective', 1),
#  ('milestones', 1),
#  ('judges', 1),
#  ('moral', 1),
#  ('utilitarianism', 1),
#  ('meta-ethics', 1),
#  ('Kantian', 1),
#  ('consequentialism', 1),
#  ('consequentialist', 1),
#  ('Capacity', 1),
#  ('Kantianism', 1),
#  ('impartial', 1),
#  ('deontology', 1),
#  ('friendship', 1),
#  ('lens', 1),
#  ('adopts', 1),
#  ('agent-centred', 1),
#  ('wrongness', 1),
#  ('judged', 1),
#  ('rightness', 1),
#  ('opposition', 1),
#  ('accompanying', 1),
#  ('love', 1),
#  ('solely', 1),
#  ('balances', 1),
#  ("auditor's", 1),
#  ('audit', 1),
#  ('materiality', 1),
#  ('opinion', 1),
#  ('ACW3041', 1),
#  ('EDP', 1),
#  ('error', 1),
#  ('auditing', 1),
#  ('auditors', 1),
#  ('audits', 1),
#  ('regulates', 1),
#  ('operators', 1),
#  ('duties', 1),
#  ('owners', 1),
#  ('advisors', 1),
#  ('advise', 1),
#  ('govern', 1),
#  ('corporations', 1),
#  ('ASIC', 1),
#  ('trusts', 1),
#  ('disputes', 1),
#  ('Osaka', 1),
#  ('intangible', 1),
#  ('contrasting', 1),
#  ('spend', 1),
#  ('starting', 1),
#  ('post-industrial', 1),
#  ('Kyushu', 1),
#  ('seaside', 1),
#  ('collections', 1),
#  ('feelings', 1),
#  ('neighbourhood', 1),
#  ('accompany', 1),
#  ('japan', 1),
#  ('Hiroshima', 1),
#  ('places', 1),
#  ('villages', 1),
#  ('famous', 1),
#  ('Kyoto', 1),
#  ('deploy', 1),
#  ('travel', 1),
#  ('discursive', 1),
#  ('level-appropriate', 1),
#  ('multifaceted', 1),
#  ('vaccines', 1),
#  ('cure', 1),
#  ('pathogens', 1),
#  ('evade', 1),
#  ('tumour', 1),
#  ('lymphoma', 1),
#  ('autoimmune', 1),
#  ('microorganisms', 1),
#  ('pathogenesis', 1),
#  ('rejection', 1),
#  ('excessive', 1),
#  ('immunopathology', 1),
#  ('immune', 1),
#  ('allergy', 1),
#  ('immunopotentiation', 1),
#  ('autoimmunity', 1),
#  ('immunosuppression', 1),
#  ('transplant', 1),
#  ('unwarranted', 1),
#  ('immunodeficiency', 1),
#  ('leukaemia', 1),
#  ('Predict', 1),
#  ('leukemia', 1),
#  ('defective', 1),
#  ('resolving', 1),
#  ('determining', 1),
#  ('voluntary', 1),
#  ('enhancement', 1),
#  ('vocal', 1),
#  ('meaningfully', 1),
#  ('facilitated', 1),
#  ('directly', 1),
#  ('Utilise', 1),
#  ('Contribute', 1),
#  ('group-tasks', 1),
#  ('computed', 1),
#  ('multi-slice', 1),
#  ('scanning', 1),
#  ('scanners', 1),
#  ('Computed', 1),
#  ('pelvis', 1),
#  ('tomography', 1),
#  ('appearances', 1),
#  ('head', 1),
#  ('tomographic', 1),
#  ('chest', 1),
#  ('spine', 1),
#  ('anatomical', 1),
#  ('reconstruction', 1),
#  ('abdomen', 1),
#  ('adult', 1),
#  ('increase', 1),
#  ('trainer', 1),
#  ('participatory', 1),
#  ('distance', 1),
#  ('facilitation', 1),
#  ('Participatory', 1),
#  ('prime', 1),
#  ('addressed', 1),
#  ('concentrations', 1),
#  ('devolve', 1),
#  ('indispensable', 1),
#  ('persuasion', 1),
#  ('check', 1),
#  ('liberal', 1),
#  ('ministers', 1),
#  ('authority', 1),
#  ('repertoires', 1),
#  ('constrained', 1),
#  ('prisoners', 1),
#  ('impinging', 1),
#  ('stock', 1),
#  ('problematic', 1),
#  ('presidents', 1),
#  ('causation', 1),
#  ('theorised', 1),
#  ('motivations', 1),
#  ('traditionally', 1),
#  ('takes', 1),
#  ('twenty-first', 1),
#  ('influential', 1),
#  ('asks', 1),
#  ('democracies', 1),
#  ('pharmacist', 1),
#  ('requiring', 1),
#  ('stewardship', 1),
#  ('antimicrobials', 1),
#  ('motivation', 1),
#  ('varying', 1),
#  ('democratic', 1),
#  ('Second', 1),
#  ('influx', 1),
#  ('Old', 1),
#  ('credentials', 1),
#  ('wake', 1),
#  ('repercussions', 1),
#  ('Prato', 1),
#  ('critics', 1),
#  ('polity', 1),
#  ('zone', 1),
#  ('peace', 1),
#  ('profound', 1),
#  ('leave', 1),
#  ('wicked', 1),
#  ('unique', 1),
#  ('Union', 1),
#  ('communist', 1),
#  ('Russia', 1),
#  ('contributed', 1),
#  ("today's", 1),
#  ('inter-play', 1),
#  ('eras', 1),
#  ('helped', 1),
#  ('distinguish', 1),
#  ('simulate', 1),
#  ('crises', 1),
#  ('pathologies', 1),
#  ('paths', 1),
#  ('secondary-source', 1),
#  ("EU's", 1),
#  ('Eurozone', 1),
#  ('achievement', 1),
#  ('resurgent', 1),
#  ('post-fascist', 1),
#  ("Union's", 1),
#  ('democracy', 1),
#  ('workplaces', 1),
#  ('Spanish', 1),
#  ('deployed', 1),
#  ('inter-cultural', 1),
#  ('shows', 1),
#  ('citizen', 1),
#  ('categories', 1),
#  ('religion', 1),
#  ('theology', 1),
#  ('nationality', 1),
#  ('sites', 1),
#  ('Studies', 1),
#  ('perceptively', 1),
#  ('logical', 1),
#  ('category', 1),
#  ('pedagogy', 1),
#  ('Examine', 1),
#  ('privileges', 1),
#  ('Arts', 1),
#  ('foregrounds', 1),
#  ('gendered', 1),
#  ('supported', 1),
#  ('limited', 1),
#  ('sports', 1),
#  ('sexualities', 1),
#  ('intersect', 1),
#  ('Relate', 1),
#  ('acting', 1),
#  ('negotiation', 1),
#  ('Challenge', 1),
#  ('partners', 1),
#  ('modules', 1),
#  ('academics', 1),
#  ('feasible', 1),
#  ('mentors', 1),
#  ('culminate', 1),
#  ('harness', 1),
#  ('utilises', 1),
#  ('dark', 1),
#  ('rigorous', 1),
#  ('true', 1),
#  ('walking', 1),
#  ('assist', 1),
#  ('hybridisation', 1),
#  ('injection', 1),
#  ('6', 1),
#  ('transplantation', 1),
#  ('widely', 1),
#  ('worked', 1),
#  ('cryopreservation', 1),
#  ('DNA', 1),
#  ('maturation', 1),
#  ('amplification', 1),
#  ('PCR', 1),
#  ('fertilization', 1),
#  ('vitro', 1),
#  ('biopsy', 1),
#  ('micromanipulation', 1),
#  ('ICSI', 1),
#  ('infertility', 1),
#  ('situ', 1),
#  ('chromosome', 1),
#  ('chromosomes', 1),
#  ('embryos', 1),
#  ('viability', 1),
#  ('single', 1),
#  ('rapidly', 1),
#  ('cryobiology', 1),
#  ('IVF', 1),
#  ('ova', 1),
#  ('embryo', 1),
#  ('preimplantation', 1),
#  ('prenatal', 1),
#  ('fluorescent', 1),
#  ('cell', 1),
#  ('comprehend', 1),
#  ('premium', 1),
#  ('intracytoplasmic', 1),
#  ('sperm', 1),
#  ('FISH', 1),
#  ('familial', 1),
#  ('polymerase', 1),
#  ('endocrinology', 1),
#  ('JavaScript', 1),
#  ('e-business', 1),
#  ('state-of', 1),
#  ('e-Business', 1),
#  ('CSS3', 1),
#  ('jQuery', 1),
#  ('APIs', 1),
#  ('oriented', 1),
#  ('MVC', 1),
#  ('JSOn', 1),
#  ('React', 1),
#  ('HTML5', 1),
#  ('nET', 1),
#  ('advent', 1),
#  ('non-B2B', 1),
#  ('Mobile', 1),
#  ('TypeScript', 1),
#  ('shared', 1),
#  ('apps', 1),
#  ('Web', 1),
#  ('ASP', 1),
#  ('2015', 1),
#  ('Angular', 1),
#  ('debug', 1),
#  ('emerged', 1),
#  ('ECMAScript', 1),
#  ('explains', 1),
#  ('W3C', 1),
#  ('Ajax', 1),
#  ('discipline-specific', 1),
#  ('protein', 1),
#  ('investigator', 1),
#  ('merit', 1),
#  ('check-points', 1),
#  ('workshop-based', 1),
#  ('downstream', 1),
#  ('candidates', 1),
#  ('bio-product', 1),
#  ('Laboratory', 1),
#  ('translational', 1),
#  ('recently', 1),
#  ('Manufacturing', 1),
#  ('promising', 1),
#  ('marketed', 1),
#  ('valuable', 1),
#  ('communicated', 1),
#  ('exciting', 1),
#  ('finding', 1),
#  ('scale-up', 1),
#  ('commercialisation', 1),
#  ('Good', 1),
#  ('enrolled', 1),
#  ('extra', 1),
#  ('argumentative', 1),
#  ('expressing', 1),
#  ('cooperative', 1),
#  ('powerful', 1),
#  ('France', 1),
#  ('transferable', 1),
#  ('exposition', 1),
#  ('explicit', 1),
#  ('Skill', 1),
#  ('katakana', 1),
#  ('dialogues', 1),
#  ('self-introductions', 1),
#  ('sociocultural', 1),
#  ('hiragana', 1),
#  ('visited', 1),
#  ('experientially', 1),
#  ('Asia-Pacific', 1),
#  ('intellectually', 1),
#  ('adapt', 1),
#  ('referral', 1),
#  ('Professional', 1),
#  ('500', 1),
#  ('assume', 1),
#  ('Code', 1),
#  ('Ethics', 1),
#  ('responsive', 1),
#  ('AAsW', 1),
#  ("provider's", 1),
#  ('self-learning', 1),
#  ('representative', 1),
#  ('renewable', 1),
#  ('sensing', 1),
#  ('simulations', 1),
#  ('telecommunications', 1),
#  ('buildings', 1),
#  ('cycle', 1),
#  ('faults', 1),
#  ('high-reliability', 1),
#  ('necessitates', 1),
#  ('transportation', 1),
#  ('root', 1),
#  ('bodies', 1),
#  ('Crimes', 1),
#  ('APEC', 1),
#  ('peacekeeping', 1),
#  ('IMF', 1),
#  ('unexplored', 1),
#  ('tribunals', 1),
#  ('Justice', 1),
#  ('reform', 1),
#  ('enforcement', 1),
#  ('presentational', 1),
#  ('Security', 1),
#  ('Council', 1),
#  ('Assembly', 1),
#  ('links', 1),
#  ('Court', 1),
#  ('General', 1),
#  ('IBRD', 1),
#  ('financing', 1),
#  ('taxation', 1),
#  ('rotary', 1),
#  ('meteorology', 1),
#  ('aero', 1),
#  ('aeromedical', 1),
#  ('aviation', 1),
#  ('surviving', 1),
#  ('CRM', 1),
#  ('Crew', 1),
#  ('retrieval', 1),
#  ('incident', 1),
#  ('Resource', 1),
#  ('fixed', 1),
#  ('self-preservation', 1),
#  ('departs', 1),
#  ('4-week', 1),
#  ('historiography', 1),
#  ('piazzas', 1),
#  ('artefact', 1),
#  ('monuments', 1),
#  ('sixteenth', 1),
#  ('duration', 1),
#  ('5', 1),
#  ('scholarship', 1),
#  ('passed', 1),
#  ('churches', 1),
#  ('Florence', 1),
#  ('city', 1),
#  ('fascinating', 1),
#  ('thirteenth', 1),
#  ('palaces', 1),
#  ('acquaintance', 1),
#  ('polemical', 1),
#  ('Enhanced', 1),
#  ('Renaissance', 1),
#  ('AtS1316', 1),
#  ('streets', 1),
#  ('mid-November', 1),
#  ('AtS1317', 1),
#  ('Lambert', 1),
#  ('polygons', 1),
#  ('compose', 1),
#  ('depictions', 1),
#  ('primitives', 1),
#  ('well-structured', 1),
#  ('decomposition', 1),
#  ('elimination', 1),
#  ('lines', 1),
#  ('output', 1),
#  ('Blinn-cook', 1),
#  ('Phong', 1),
#  ('homogeneous', 1),
#  ('Blinns', 1),
#  ('textures', 1),
#  ('coordinates', 1),
#  ('polyhedral', 1),
#  ('projections', 1),
#  ('Oren-Nayar', 1),
#  ('graphics', 1),
#  ('API', 1),
#  ('shadows', 1),
#  ('affine', 1),
#  ('Beckmann', 1),
#  ('ray-tracing', 1),
#  ('shading', 1),
#  ('hidden', 1),
#  ('radiosity', 1),
#  ('2D', 1),
#  ('realistic', 1),
#  ('BRDF', 1),
#  ('Torrance-Sparrow', 1),
#  ('decompose', 1),
#  ('throughput', 1),
#  ('highlighted', 1),
#  ('targets', 1),
#  ('targeted', 1),
#  ('Source', 1),
#  ('genomics', 1),
#  ('Obtain', 1),
#  ('illustrating', 1),
#  ('desired', 1),
#  ('screens', 1),
#  ('notion', 1),
#  ('statuses', 1),
#  ('adopted', 1),
#  ('tendencies', 1),
#  ('phonological', 1),
#  ('englishes', 1),
#  ('realms', 1),
#  ('english', 1),
#  ('upshots', 1),
#  ('varieties', 1),
#  ('non-standard', 1),
#  ('Australasia', 1),
#  ('distinctive', 1),
#  ('nudge', 1),
#  ('obesity', 1),
#  ('pandemics', 1),
#  ('fastest', 1),
#  ('medicines', 1),
#  ('tobacco', 1),
#  ('bioethics', 1),
#  ('coverage', 1),
#  ('subdisciplines', 1),
#  ('vaccination', 1),
#  ('well-argued', 1),
#  ('Science', 1),
#  ('exploratory', 1),
#  ('predictive', 1),
#  ('scripting', 1),
#  ('underlie', 1),
#  ('inferential', 1),
#  ('Data', 1),
#  ('toolkits', 1),
#  ('sensor', 1),
#  ('atoms', 1),
#  ('entropy', 1),
#  ('reactions', 1),
#  ('periodic', 1),
#  ('exploiting', 1),
#  ('Interpret', 1),
#  ('stereochemistry', 1),
#  ('intermolecular', 1),
#  ('reactivity', 1),
#  ('redox', 1),
#  ('cHM1022', 1),
#  ('acid-base', 1),
#  ('molecules', 1),
#  ('enthalpy', 1),
#  ('bonding', 1),
#  ('chemists', 1),
#  ('polarity', 1),
#  ('presumed', 1),
#  ('ideal', 1),
#  ('stoichiometry', 1),
#  ('table', 1),
#  ('cHM1011', 1),
#  ('gases', 1),
#  ('Foster', 1),
#  ('electrochemistry', 1),
#  ('thermodynamics', 1),
#  ('isomerism', 1),
#  ('inquiry-based', 1),
#  ('affects', 1),
#  ('equilibria', 1),
#  ('atomic', 1),
#  ('chirality', 1),
#  ('faced', 1),
#  ('pertaining', 1),
#  ('prehospital', 1),
#  ('self-care', 1),
#  ('paramedics', 1),
#  ('ambulance', 1),
#  ('uninterrupted', 1),
#  ('macroscopic', 1),
#  ('interrupted', 1),
#  ('Dynamic', 1),
#  ('Systems', 1),
#  ('Intelligent', 1),
#  ('microscopic', 1),
#  ('AsP4000', 1),
#  ('Geophysics', 1),
#  ('Atmosphere', 1),
#  ('Atmospheric', 1),
#  ('Earth', 1),
#  ('coursework', 1),
#  ('Geology', 1),
#  ('EAE4200', 1),
#  ('span', 1),
#  ('School', 1),
#  ('Sciences', 1),
#  ('raise', 1),
#  ('brands', 1),
#  ('advertising', 1),
#  ('terminologies', 1),
#  ('sales', 1),
#  ('scheduling', 1),
#  ('publicity', 1),
#  ('television', 1),
#  ('Radio', 1),
#  ('day-to', 1),
#  ('radio', 1),
#  ('day', 1),
#  ('edit', 1),
#  ('news', 1),
#  ('broadcast', 1),
#  ('bulletins', 1),
#  ('APG5095', 1),
#  ('live', 1),
#  ('affairs', 1),
#  ('purpose-built', 1),
#  ('broadcasting', 1),
#  ('APG5096', 1),
#  ('legislative', 1),
#  ('eDM', 1),
#  ('Ability', 1),
#  ('mitigating', 1),
#  ('aiding', 1),
#  ('rejected', 1),
#  ('Southern', 1),
#  ('decision-makers', 1),
#  ('eIA', 1),
#  ('geometry', 1),
#  ('texturing', 1),
#  ('geometrical', 1),
#  ('lighting', 1),
#  ("one's", 1),
#  ('half', 1),
#  ('actions', 1),
#  ('1945-1990', 1),
#  ('queer', 1),
#  ('Western', 1),
#  ('canon', 1),
#  ('art-historical', 1),
#  ('previously', 1),
#  ('incorporating', 1),
#  ('feminist', 1),
#  ('exclude', 1),
#  ('constructions', 1),
#  ('non-Western', 1),
#  ('Employ', 1),
#  ('thoughtfully', 1),
#  ('excluded', 1),
#  ('AsP4002Not', 1),
#  ('interim', 1),
#  ('scenario-based', 1),
#  ('grading', 1),
#  ('client-centred', 1),
#  ('adaptation', 1),
#  ('allocation', 1),
#  ('Clearly', 1),
#  ('goal', 1),
#  ('retrieve', 1),
#  ('underpinnings', 1),
#  ('employers', 1),
#  ('wastes', 1),
#  ('legislated', 1),
#  ('Health', 1),
#  ('excursions', 1),
#  ('programmed', 1),
#  ('Safety', 1),
#  ('Recommend', 1),
#  ('disposal', 1),
#  ('dangerous', 1),
#  ('hazardous', 1),
#  ('supervisors', 1),
#  ('recycling', 1),
#  ('impose', 1),
#  ('scientists', 1),
#  ('consisting', 1),
#  ('expect', 1),
#  ('highly', 1),
#  ('secure', 1),
#  ('usage', 1),
#  ('expectations', 1),
#  ('valued', 1),
#  ('thrive', 1),
#  ('editing', 1),
#  ('writer', 1),
#  ('globe', 1),
#  ('spans', 1),
#  ('LARP', 1),
#  ('nonrenewable', 1),
#  ('efficiency', 1),
#  ('semiconductors', 1),
#  ('generation', 1),
#  ('thermoelectric', 1),
#  ('revolutionise', 1),
#  ('characterization', 1),
#  ('included', 1),
#  ('piezoelectric', 1),
#  ('storage', 1),
#  ('fuel', 1),
#  ('photovoltaics', 1),
#  ('option', 1),
#  ('solar', 1),
#  ('reliance', 1),
#  ('hydrogen', 1),
#  ('utilisation', 1),
#  ('negative', 1),
#  ('structure-property', 1),
#  ('conversion', 1),
#  ('lifelong', 1),
#  ('attributed', 1),
#  ('healing', 1),
#  ('Torres', 1),
#  ('pre-colonisation', 1),
#  ('reciprocity', 1),
#  ('aboriginal', 1),
#  ('humility', 1),
#  ('oldest', 1),
#  ('PC-based', 1),
#  ('Wireless', 1),
#  ('cryptographic', 1),
#  ('firewall', 1),
#  ('confidentiality', 1),
#  ('Private', 1),
#  ('privacy', 1),
#  ('OSI', 1),
#  ('protect', 1),
#  ('disguise', 1),
#  ('reduce', 1),
#  ('compliance', 1),
#  ('Networks', 1),
#  ('authentication', 1),
#  ('mail', 1),
#  ('signatures', 1),
#  ('defence', 1),
#  ('Internet', 1),
#  ('intruders', 1),
#  ('intrusion', 1),
#  ('non-repudiation', 1),
#  ('encryption', 1),
#  ('Wired', 1),
#  ('vulnerabilities', 1),
#  ('configurations', 1),
#  ('malicious', 1),
#  ('authenticity', 1),
#  ('Vitual', 1),
#  ('personalities', 1),
#  ('convictions', 1),
#  ('aspiring', 1),
#  ('discern', 1),
#  ('featured', 1),
#  ('inspiring', 1),
#  ('failures', 1),
#  ('exemplary', 1),
#  ('crucial', 1),
#  ('compassionate', 1),
#  ('character', 1),
#  ('role-plays', 1),
#  ('growth', 1),
#  ('aspirations', 1),
#  ('plethora', 1),
#  ('lessons', 1),
#  ('self-assessments', 1),
#  ('successes', 1),
#  ('movies', 1),
#  ('videos', 1),
#  ('journey', 1),
#  ('laid', 1),
#  ('begun', 1),
#  ('ATS1211', 1),
#  ('Ukrainian', 1),
#  ('geoscientific', 1),
#  ('geochemical', 1),
#  ('comparable', 1),
#  ('Students', 1),
#  ('mineral', 1),
#  ('simulates', 1),
#  ('geological', 1),
#  ('post-graduate', 1),
#  ('work-integrated', 1),
#  ('geophysical', 1),
#  ('commodity', 1),
#  ('continues', 1),
#  ('mediums', 1),
#  ('Contextualise', 1),
#  ('advance', 1),
#  ('Register', 1),
#  ('letter', 1),
#  ('charts', 1),
#  ('specifications', 1),
#  ('Safe', 1),
#  ('productivities', 1),
#  ('administration', 1),
#  ('tenderer', 1),
#  ('preferred', 1),
#  ('parties', 1),
#  ('acceptance', 1),
#  ('calculation', 1),
#  ('Test', 1),
#  ('load', 1),
#  ('subcontractor', 1),
#  ('sequencing', 1),
#  ('supplied', 1),
#  ('Quality', 1),
#  ('HSQE', 1),
#  ('Microsoft', 1),
#  ('SWMS', 1),
#  ('Method', 1),
#  ('Statement', 1),
#  ('dispute', 1),
#  ('quotes', 1),
#  ('Inspection', 1),
#  ('crane', 1),
#  ('Impacts', 1),
#  ('spread', 1),
#  ('factor', 1),
#  ('communicable', 1),
#  ('immunisation', 1),
#  ('vector', 1),
#  ('outbreaks', 1),
#  ('therapies', 1),
#  ('Zionism', 1),
#  ('move', 1),
#  ('19th', 1),
#  ('Muslims', 1),
#  ('helping', 1),
#  ('begin', 1),
#  ('nation-states', 1),
#  ('Holocaust', 1),
#  ('tolerance', 1),
#  ('Enlightenment', 1),
#  ('Middle', 1),
#  ('minorities', 1),
#  ('emigration', 1),
#  ('tracing', 1),
#  ('trace', 1),
#  ('Christians', 1),
#  ('positions', 1),
#  ('Israel', 1),
#  ('sparked', 1),
#  ('colonization', 1),
#  ('unpack', 1),
#  ('Jews', 1),
#  ('misunderstanding', 1),
#  ('mobility', 1),
#  ('paediatric', 1),
#  ('transmitted', 1),
#  ('sexually', 1),
#  ('medico-legal', 1),
#  ('protective', 1),
#  ('genital', 1),
#  ('police', 1),
#  ('suspected', 1),
#  ('encompasses', 1),
#  ('lawyers', 1),
#  ('parent-report', 1),
#  ('wishing', 1),
#  ('critiqued', 1),
#  ('paid', 1),
#  ('family-centred', 1),
#  ('suited', 1),
#  ('naturalistic', 1),
#  ('incomes', 1),
#  ('Accounting', 1),
#  ('exercise', 1),
#  ('Conceptual', 1),
#  ('double-entry', 1),
#  ('Standards', 1),
#  ('prepared', 1),
#  ('expenses', 1),
#  ('accrual', 1),
#  ('globalization', 1),
#  ('africa', 1),
#  ('Cold', 1),
#  ('re-making', 1),
#  ('pronounced', 1),
#  ('fundamentalisms', 1),
#  ('reconceived', 1),
#  ('Russian', 1),
#  ('nationalism', 1),
#  ('distinctions', 1),
#  ('Revolution', 1),
#  ('empires', 1),
#  ('Nazism', 1),
#  ('asia', 1),
#  ('capitalism', 1),
#  ('revolution', 1),
#  ('revolutionary', 1),
#  ('The', 1),
#  ('wars', 1),
#  ('freedom', 1),
#  ('constitutive', 1),
#  ('nations', 1),
#  ('Fascism', 1),
#  ('revolutions', 1),
#  ('cold', 1),
#  ('interwar', 1),
#  ('continued', 1),
#  ('deck', 1),
#  ('condition', 1),
#  ('limit', 1),
#  ('highway', 1),
#  ('descriptions', 1),
#  ('fatigue', 1),
#  ('beams', 1),
#  ('prestressed', 1),
#  ('rating', 1),
#  ('degradation', 1),
#  ('prevalent', 1),
#  ('rehabilitation', 1),
#  ('qualitatively', 1),
#  ('inspection', 1),
#  ('life-cycle', 1),
#  ('quantitatively', 1),
#  ('time-dependent', 1),
#  ('subjected', 1),
#  ('serviceability', 1),
#  ('computer-based', 1),
#  ('members', 1),
#  ('repair', 1),
#  ('deformations', 1),
#  ('supporting', 1),
#  ('bridges', 1),
#  ('expressions', 1),
#  ('exponential', 1),
#  ('domain', 1),
#  ('inverse', 1),
#  ('trigonometric', 1),
#  ('algebra', 1),
#  ('differentiation', 1),
#  ...]

# %% [markdown]
# ## 10. Remove rare tokens

# %%
#getting list of less than 5%
list_of_leastcommon = []
for i in p:
    word,freq = i
    if freq < 0.05 * len(sum1):
        pe = (word, freq)
        list_of_leastcommon.append(word)
print(len(list_of_leastcommon))
# Out:
# 3685

# %%
both_removed = []
for k, v in tokenized_units_1.items():
    # using list comprehension for filtering out tokens
    tokenized_units_1[k]=[i for i in v if i not in list_of_leastcommon]

countwords=list(chain.from_iterable(tokenized_units_1.values()))
a=set(countwords)
b=list(a)
print(len(b))
# Out:
# 259

# %% [markdown]
# ## 11. Stemming using Porter Stemmer
# The stemming process is done using Porter Stemmer.I've performed the stemming on updated
# vocabulary. The code below is in reference to the lecture file.

# %%
stemmer = PorterStemmer()

new=['{1}'.format(w, stemmer.stem(w)) for w in b]
print((new))
# Out:
# ['cover', 'conceptu', 'base', 'relat', 'health', 'servic', 'abil', 'approach', 'question', 'select', 'solv', 'appreci', 'intern', 'engag', 'studi', 'strategi', 'understand', 'practic', 'commun', 'complex', 'synthesis', 'demonstr', 'financi', 'limit', 'group', 'project', 'structur', 'natur', 'includ', 'program', 'introduc', 'framework', 'methodolog', 'interpret', 'practic', 'work', 'develop', 'fundament', 'polit', 'divers', 'assess', 'student', 'theoret', 'evalu', 'analys', 'laboratori', 'introduct', 'examin', 'learn', 'concept', 'perspect', 'text', 'present', 'system', 'ethic', 'demonstr', 'high', 'commun', 'construct', 'element', 'independ', 'compon', 'role', 'social', 'methodolog', 'oral', 'unit', 'ethic', 'analyt', 'problem', 'conduct', 'report', 'cultur', 'aim', 'data', 'implic', 'examin', 'complet', 'work', 'identifi', 'decis', 'critic', 'evid', 'disciplin', 'influenc', 'address', 'studio', 'inform', 'global', 'australia', 'relat', 'common', 'product', 'approach', 'public', 'challeng', 'literatur', 'explor', 'key', 'aspect', 'apprais', 'develop', 'order', 'system', 'world', 'undertak', 'studi', 'standard', 'polici', 'engin', 'advanc', 'set', 'concept', 'assess', 'process', 'critic', 'physic', 'case', 'primari', 'techniqu', 'issu', 'write', 'program', 'treatment', 'explor', 'process', 'appli', 'project', 'relationship', 'understand', 'solut', 'implement', 'effect', 'cover', 'control', 'relat', 'plan', 'local', 'societi', 'comprehens', 'relev', 'visual', 'qualiti', 'medic', 'perform', 'experi', 'develop', 'write', 'discuss', 'industri', 'effect', 'occup', 'clinic', 'materi', 'sourc', 'materi', 'written', 'number', 'requir', 'field', 'prepar', 'rang', 'method', 'level', 'develop', 'histor', 'tool', 'involv', 'appli', 'histori', 'think', 'environment', 'learn', 'identifi', 'human', 'manag', 'articul', 'introduc', 'topic', 'design', 'condit', 'make', 'plan', 'problem', 'scientif', 'model', 'individu', 'design', 'prepar', 'understand', 'academ', 'procedur', 'profession', 'awar', 'rule', 'knowledg', 'activ', 'modern', 'individu', 'perspect', 'opportun', 'present', 'team', 'level', 'applic', 'languag', 'cultur', 'make', 'research', 'idea', 'skill', 'analysi', 'acquisit', 'recognis', 'technolog', 'experi', 'specif', 'select', 'environ', 'cultur', 'focus', 'includ', 'varieti', 'aim', 'outcom', 'appli', 'explain', 'applic', 'framework', 'type', 'major', 'find', 'deliveri', 'context', 'commun', 'area', 'principl', 'area', 'context', 'critic', 'reflect', 'legal', 'contemporari', 'theori', 'describ', 'behaviour', 'student', 'safeti', 'import', 'effect', 'impact', 'theori', 'busi', 'care', 'present', 'focu', 'develop', 'basic', 'practic']

# %% [markdown]
# # 12. Writing the vocab.txt file
# After the pre processing is done, with the cleaned output I am creating a vocabulary by extracting all tokens from all units combined and set it to make it unique. A vocab file is created in this step that should have vocab and index which will be used for creating count vector. The output of this step should be a file text containing all indexed vocabs.

# %%
vocab = list(set(new))
vocab.sort()# sort vocabs alphabetically
# Out:
# 199

# %%
integer_index = list(range(0,len(vocab)))

# %%
#open vocab file
f = open("vocab.txt", "w+")

i = 0
while i < len(vocab)-1: # create loop only until second to last index because I will write comma after each vocab
    f.write(vocab[i] + ":" + str(integer_index[i]) + "," + "\r\n")
    i += 1
